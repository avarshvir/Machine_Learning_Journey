# %%
import pandas as pd

# %%
data = pd.read_csv("E:\Machine_Learning_Journey\Machine_Learning_Journey\data_sets\social_ads.csv")

# %%
data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
data['EstimatedSalary'].max()
# Out:
# 150000

# %%
data['EstimatedSalary'].min()
# Out:
# 15000

# %%
data.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
import matplotlib.pyplot as plt

# %%
data.plot(kind='bar')
# Out:
# <Axes: >

# %%
data2 = data.copy()

# %%
data2
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
for col in data2.columns:
    data2[col] = data2[col]/data2[col].abs().max()

# %%
data2
# Out:
#           Age  EstimatedSalary  Purchased
# 0    0.316667         0.126667        0.0
# 1    0.583333         0.133333        0.0
# 2    0.433333         0.286667        0.0
# 3    0.450000         0.380000        0.0
# 4    0.316667         0.506667        0.0
# ..        ...              ...        ...
# 395  0.766667         0.273333        1.0
# 396  0.850000         0.153333        1.0
# 397  0.833333         0.133333        1.0
# 398  0.600000         0.220000        0.0
# 399  0.816667         0.240000        1.0
#
# [400 rows x 3 columns]

# %%
data2.plot(kind='bar')
# Out:
# <Axes: >

# %%
data3 = data.copy()

# %%
for col in data3['EstimatedSalary']:
    data3['EstimatedSalary'] = data3['EstimatedSalary']/data3['EstimatedSalary'].abs().max()

# %%
data3
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19         0.126667          0
# 1     35         0.133333          0
# 2     26         0.286667          0
# 3     27         0.380000          0
# 4     19         0.506667          0
# ..   ...              ...        ...
# 395   46         0.273333          1
# 396   51         0.153333          1
# 397   50         0.133333          1
# 398   36         0.220000          0
# 399   49         0.240000          1
#
# [400 rows x 3 columns]

# %%
data3.plot(kind='bar')
# Out:
# <Axes: >
