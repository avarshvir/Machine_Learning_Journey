# %%
import pandas as pd
from sklearn.preprocessing import MaxAbsScaler

# %%
data = pd.read_csv("E:\Machine_Learning_Journey\Machine_Learning_Journey\data_sets\social_ads.csv")

# %%
data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
data2 = data.copy()

# %%
data2['EstimatedSalary'].max()
# Out:
# 150000

# %%
data2['EstimatedSalary'].min()
# Out:
# 15000

# %%
mas = MaxAbsScaler()

# %%
scaled_salary = mas.fit_transform(data2[['EstimatedSalary']])

# %%
scaled_salary
# Out:
# array([[0.12666667],
#        [0.13333333],
#        [0.28666667],
#        [0.38      ],
#        [0.50666667],
#        [0.38666667],
#        [0.56      ],
#        [1.        ],
#        [0.22      ],
#        [0.43333333],
#        [0.53333333],
#        [0.34666667],
#        [0.57333333],
#        [0.12      ],
#        [0.54666667],
#        [0.53333333],
#        [0.16666667],
#        [0.17333333],
#        [0.18666667],
#        [0.19333333],
#        [0.14666667],
#        [0.32666667],
#        [0.27333333],
#        [0.14666667],
#        [0.15333333],
#        [0.13333333],
#        [0.18666667],
#        [0.2       ],
#        [0.28666667],
#        [0.12      ],
#        [0.49333333],
#        [0.91333333],
#        [0.10666667],
#        [0.29333333],
#        [0.6       ],
#        [0.18      ],
#        [0.18666667],
#        [0.32666667],
#        [0.48      ],
#        [0.20666667],
#        [0.11333333],
#        [0.34      ],
#        [0.72      ],
# ...

# %%
data2
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
data2['scaled_salary'] = scaled_salary

# %%
data2
# Out:
#      Age  EstimatedSalary  Purchased  scaled_salary
# 0     19            19000          0       0.126667
# 1     35            20000          0       0.133333
# 2     26            43000          0       0.286667
# 3     27            57000          0       0.380000
# 4     19            76000          0       0.506667
# ..   ...              ...        ...            ...
# 395   46            41000          1       0.273333
# 396   51            23000          1       0.153333
# 397   50            20000          1       0.133333
# 398   36            33000          0       0.220000
# 399   49            36000          1       0.240000
#
# [400 rows x 4 columns]

# %%
data2.describe()
# Out:
#               Age  EstimatedSalary   Purchased  scaled_salary
# count  400.000000       400.000000  400.000000     400.000000
# mean    37.655000     69742.500000    0.357500       0.464950
# std     10.482877     34096.960282    0.479864       0.227313
# min     18.000000     15000.000000    0.000000       0.100000
# 25%     29.750000     43000.000000    0.000000       0.286667
# 50%     37.000000     70000.000000    0.000000       0.466667
# 75%     46.000000     88000.000000    1.000000       0.586667
# max     60.000000    150000.000000    1.000000       1.000000
