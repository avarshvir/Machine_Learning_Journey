# %%
import pandas as pd

# %%
data = pd.read_csv("E:\Machine_Learning_Journey\Machine_Learning_Journey\data_sets\iris_dataset.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           NaN            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.drop('Id',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.columns = ['Sepal_L','Sepal_W','Petal_L','Petal_W','Species']

# %%
data
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 3        NaN      3.1      1.5      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      NaN      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.drop(3,axis=0,inplace = True)

# %%
data
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      NaN      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data.dropna()
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 144      6.7      3.3      5.7      2.5  Iris-virginica
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [119 rows x 5 columns]

# %%
data
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      NaN      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data.dropna(thresh = 4)
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      NaN      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [145 rows x 5 columns]

# %%
data.dropna(how = 'all')
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      NaN      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
"""how='any' (default):
Drops a row or column if any of its values are missing (NaN).
how='all':
Drops a row or column only if all of its values are missing (NaN)."""
data.dropna(subset = 'Species')
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      NaN      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      NaN      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 144      6.7      3.3      5.7      2.5  Iris-virginica
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [119 rows x 5 columns]

# %%
data.dropna(axis = 1)
# Out:
#      Sepal_L  Sepal_W  Petal_L  Petal_W         Species
# 0        5.1      3.5      1.4      0.2     Iris-setosa
# 1        4.9      3.0      1.4      0.2     Iris-setosa
# 2        4.7      3.2      1.3      0.2     Iris-setosa
# 4        5.0      3.6      1.4      0.2     Iris-setosa
# 5        5.4      3.9      1.7      0.4     Iris-setosa
# ..       ...      ...      ...      ...             ...
# 144      6.7      3.3      5.7      2.5  Iris-virginica
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica
#
# [119 rows x 5 columns]
