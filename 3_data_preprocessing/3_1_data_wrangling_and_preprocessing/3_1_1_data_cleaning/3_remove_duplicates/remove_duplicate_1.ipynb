# %% [markdown]
# ## Removing Duplicate Column

# %%
import pandas as pd

# %%
data = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Alice', 'David'],
    'Age': [25, 30, 25, 40],
    'City': ['NY', 'LA', 'NY', 'SF']
})

# %%
data
# Out:
#     Name  Age City
# 0  Alice   25   NY
# 1    Bob   30   LA
# 2  Alice   25   NY
# 3  David   40   SF
