# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://thegreatestbooks.org/"

# %%
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content,'html5lib')

# %%
print(soup.prettify())
