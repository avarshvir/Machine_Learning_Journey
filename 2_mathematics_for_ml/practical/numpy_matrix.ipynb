# %%
import numpy as np

# %%
A = np.array([[1,2],[3,4]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B = np.array([[5,6],[7,8]])

# %%
B
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
result = np.dot(A,B)

# %%
result
# Out:
# array([[19, 22],
#        [43, 50]])
