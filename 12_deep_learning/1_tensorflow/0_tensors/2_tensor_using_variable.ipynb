# %%
import tensorflow as tf

# %%
tensor = tf.Variable([1,2,3])

# %%
tensor
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %%
print(tensor.numpy())
# Out:
# [1 2 3]

# %%
const_tensor = tf.constant([1,2,3])

# %%
const_tensor
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %%
print(const_tensor.numpy())
# Out:
# [1 2 3]

# %%
tensor[1].assign(5)
# Out:
# <tf.Variable 'UnreadVariable' shape=(3,) dtype=int32, numpy=array([1, 5, 3], dtype=int32)>

# %%
const_tensor[1].assign(5) #-> error
