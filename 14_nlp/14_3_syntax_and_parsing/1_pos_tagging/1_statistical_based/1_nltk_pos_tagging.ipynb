# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
text = "My Name Is Arshvir And I Love NLP."

# %%
tokens = word_tokenize(text)

# %%
print(pos_tag(tokens))
# Out:
# [('My', 'PRP$'), ('Name', 'NN'), ('Is', 'VBZ'), ('Arshvir', 'NNP'), ('And', 'CC'), ('I', 'PRP'), ('Love', 'VBP'), ('NLP', 'NNP'), ('.', '.')]

# %%
text2 = "The Quick Brown Fox Jumps Over Lazy Dog"

# %%
tokens2 = word_tokenize(text2)

# %%
print(pos_tag(tokens2))
# Out:
# [('The', 'DT'), ('Quick', 'NNP'), ('Brown', 'NNP'), ('Fox', 'NNP'), ('Jumps', 'NNP'), ('Over', 'NNP'), ('Lazy', 'NNP'), ('Dog', 'NNP')]

# %%
text3 = "My name is Arshvir and I love NLP."

# %%
tokens3 = word_tokenize(text3)

# %%
print(pos_tag(tokens3))
# Out:
# [('My', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Arshvir', 'NNP'), ('and', 'CC'), ('I', 'PRP'), ('love', 'VBP'), ('NLP', 'NNP'), ('.', '.')]

# %%
text4 = "The quick brown fox jumps over lazy dog"

# %%
tokens4 = word_tokenize(text4)

# %%
print(pos_tag(tokens4))
# Out:
# [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('lazy', 'JJ'), ('dog', 'NN')]

# %%
text5 = "My name is Arshvir and I love NLP."

# %%
tokens5 = word_tokenize(text5.lower())

# %%
print(pos_tag(tokens5))
# Out:
# [('my', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('arshvir', 'JJ'), ('and', 'CC'), ('i', 'JJ'), ('love', 'VBP'), ('nlp', 'NN'), ('.', '.')]

# %%
text6 = "The quick brown fox jumps over lazy dog"

# %%
tokens6 = word_tokenize(text6.lower())

# %%
print(pos_tag(tokens6))
# Out:
# [('the', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('lazy', 'JJ'), ('dog', 'NN')]

# %%
text6 = "my name is Arshvir and i love nlp."

# %%
tokens6 = word_tokenize(text6)

# %%
print(pos_tag(tokens6))
# Out:
# [('my', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('Arshvir', 'NNP'), ('and', 'CC'), ('i', 'VB'), ('love', 'VBP'), ('nlp', 'NN'), ('.', '.')]
