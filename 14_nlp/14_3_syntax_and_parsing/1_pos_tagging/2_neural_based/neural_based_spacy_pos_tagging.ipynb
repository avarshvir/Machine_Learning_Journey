# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = "My Name Is Arshvir And I Love NLP."

# %%
doc = nlp(text.lower())

# %%
for token in doc:
  print(token.text + ": " + token.pos_)
# Out:
# my: PRON
# name: NOUN
# is: AUX
# arshvir: PROPN
# and: CCONJ
# i: PRON
# love: VERB
# nlp: PROPN
# .: PUNCT
