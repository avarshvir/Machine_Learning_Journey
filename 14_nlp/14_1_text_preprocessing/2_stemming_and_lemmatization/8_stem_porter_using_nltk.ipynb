# %%
import nltk

# %%
#not required for stemmer
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
words = ["study", "studying", "studies", "studied", "studious"]

# %%
for w in words:
  print (w, ":", ps.stem(w))
# Out:
# study : studi
# studying : studi
# studies : studi
# studied : studi
# studious : studiou

# %%
text = "NLTK includes several stemming algorithms running, runner, runs, easily, fairer."

# %%
#for w in text.split():
#  print (w, ":", ps.stem(w))
# Out:
# NLTK : nltk
# includes : includ
# several : sever
# stemming : stem
# algorithms : algorithm
# running, : running,
# runner, : runner,
# runs, : runs,
# easily, : easily,
# fairer. : fairer.

# %%
from nltk.tokenize import word_tokenize

# %%
tokenize_text = word_tokenize(text)

# %%
tokenize_text
# Out:
# ['NLTK',
#  'includes',
#  'several',
#  'stemming',
#  'algorithms',
#  'running',
#  ',',
#  'runner',
#  ',',
#  'runs',
#  ',',
#  'easily',
#  ',',
#  'fairer',
#  '.']

# %%
for w in tokenize_text:
  print(w, ":", ps.stem(w))
# Out:
# NLTK : nltk
# includes : includ
# several : sever
# stemming : stem
# algorithms : algorithm
# running : run
# , : ,
# runner : runner
# , : ,
# runs : run
# , : ,
# easily : easili
# , : ,
# fairer : fairer
# . : .

# %%
ps.stem("easily")
#output - 'easili'
