# %%
# !pip install spaCy

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import spacy
#
# File d:\Program Files\Python org\Lib\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File d:\Program Files\Python org\Lib\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File d:\Program Files\Python org\Lib\site-packages\spacy\compat.py:39
#      36 except ImportError:
# ...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = "Hello World! NLP is fun."

# %%
text
# Out:
# 'Hello World! NLP is fun.'

# %%
doc = nlp(text)

# %%
doc
# Out:
# Hello World! NLP is fun.

# %%
words = [token.text for token in doc]

# %%
words
# Out:
# ['Hello', 'World', '!', 'NLP', 'is', 'fun', '.']

# %%
text2 = "Hi, Mam"
