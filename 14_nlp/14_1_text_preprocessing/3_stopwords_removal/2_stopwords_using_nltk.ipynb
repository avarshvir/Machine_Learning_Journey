# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
sentence = "This is an example showing off stop word filtration."

# %%
tokens = sentence.lower().split()

# %%
tokens
# Out:
# ['this',
#  'is',
#  'an',
#  'example',
#  'showing',
#  'off',
#  'stop',
#  'word',
#  'filtration.']

# %%
final_sentence = [word for word in tokens if word not in stop_words]

# %%
print(sentence)
print("-"*80)
print(final_sentence)
# Out:
# This is an example showing off stop word filtration.
# --------------------------------------------------------------------------------
# ['example', 'showing', 'stop', 'word', 'filtration.']

# %%
# See all available languages
print("Available languages:", stopwords.fileids())
# Out:
# Available languages: ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish']

# %%
stop_words2 = set(stopwords.words('hinglish'))

# %%
sentence2 = "app kese ho mein boht acha hoon."

# %%
tokens2 = sentence2.lower().split()

# %%
final_sentence2 = [word for word in tokens2 if word not in stop_words2]

# %%
final_sentence2
# Out:
# ['app', 'kese', 'boht', 'hoon.']
