# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 65.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp= spacy.load('en_core_web_sm')

# %%
st1= nlp("The tiger (Panthera tigris) is a large cat and a member of the genus Panthera native to Asia. It has a powerful, muscular body with a large head and paws, a long tail and orange fur with black, mostly vertical stripes. It is traditionally classified into nine recent subspecies, though some recognise only two subspecies, mainland Asian tigers and the island tigers of the Sunda Islands.")

# %%
st1
# Out:
# The tiger (Panthera tigris) is a large cat and a member of the genus Panthera native to Asia. It has a powerful, muscular body with a large head and paws, a long tail and orange fur with black, mostly vertical stripes. It is traditionally classified into nine recent subspecies, though some recognise only two subspecies, mainland Asian tigers and the island tigers of the Sunda Islands.

# %%
for i in st1.sents:
    print(i)
# Out:
# The tiger (Panthera tigris) is a large cat and a member of the genus Panthera native to Asia.
# It has a powerful, muscular body with a large head and paws, a long tail and orange fur with black, mostly vertical stripes.
# It is traditionally classified into nine recent subspecies, though some recognise only two subspecies, mainland Asian tigers and the island tigers of the Sunda Islands.

# %%
st2 = nlp("India, officially the Republic of India, is a country in South Asia. It is the seventh-largest country by area; the most populous country from June 2023 onwards; and since its independence in 1947, the world's most populous democracy. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.")

# %%
st2
# Out:
# India, officially the Republic of India, is a country in South Asia. It is the seventh-largest country by area; the most populous country from June 2023 onwards; and since its independence in 1947, the world's most populous democracy. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.

# %%
for i in st2.sents:
    print(i)
# Out:
# India, officially the Republic of India, is a country in South Asia.
# It is the seventh-largest country by area; the most populous country from June 2023 onwards; and since its independence in 1947, the world's most populous democracy.
# Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east.
# In the Indian Ocean, India is near Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand, Myanmar, and Indonesia.

# %%
# word tokenization

# %%
st3 = nlp("Dr. Strange is one of the best Jaadugar in the world. He. is specialist in jaaadu.")

# %%
st3
# Out:
# Dr. Strange is one of the best Jaadugar in the world. He. is specialist in jaaadu.

# %%
for i in st3.sents:
    for j in i:
        print(j)
# Out:
# Dr.
# Strange
# is
# one
# of
# the
# best
# Jaadugar
# in
# the
# world
# .
# He
# .
# is
# specialist
# in
# jaaadu
# .

# %%
det= nlp("My mail id is abc@example.com.")

# %%
for i in det:
    if i.like_email:
       print(i)
# Out:
# abc@example.com

# %%
# POS tagging

# %%
doc= nlp("Dr. Strange is one of the best Jaadugar in the world. He is specialist in jaaadu.Ticket for his show is 5$")

# %%
for i in doc:
    print("Token is ",i,"----","POS is ",i.pos_,"--",spacy.explain(i.pos_))
# Out:
# Token is  Dr. ---- POS is  PROPN -- proper noun
# Token is  Strange ---- POS is  PROPN -- proper noun
# Token is  is ---- POS is  AUX -- auxiliary
# Token is  one ---- POS is  NUM -- numeral
# Token is  of ---- POS is  ADP -- adposition
# Token is  the ---- POS is  DET -- determiner
# Token is  best ---- POS is  ADJ -- adjective
# Token is  Jaadugar ---- POS is  PROPN -- proper noun
# Token is  in ---- POS is  ADP -- adposition
# Token is  the ---- POS is  DET -- determiner
# Token is  world ---- POS is  NOUN -- noun
# Token is  . ---- POS is  PUNCT -- punctuation
# Token is  He ---- POS is  PRON -- pronoun
# Token is  is ---- POS is  AUX -- auxiliary
# Token is  specialist ---- POS is  ADJ -- adjective
# Token is  in ---- POS is  ADP -- adposition
# Token is  jaaadu ---- POS is  NOUN -- noun
# Token is  . ---- POS is  PUNCT -- punctuation
# Token is  Ticket ---- POS is  NOUN -- noun
# Token is  for ---- POS is  ADP -- adposition
# Token is  his ---- POS is  PRON -- pronoun
# ...

# %%
#lemmitization

# %%
for i in doc:
    print("Token is ",i,"----","Lemma is ",i.lemma_)
# Out:
# Token is  Dr. ---- Lemma is  Dr.
# Token is  Strange ---- Lemma is  Strange
# Token is  is ---- Lemma is  be
# Token is  one ---- Lemma is  one
# Token is  of ---- Lemma is  of
# Token is  the ---- Lemma is  the
# Token is  best ---- Lemma is  good
# Token is  Jaadugar ---- Lemma is  Jaadugar
# Token is  in ---- Lemma is  in
# Token is  the ---- Lemma is  the
# Token is  world ---- Lemma is  world
# Token is  . ---- Lemma is  .
# Token is  He ---- Lemma is  he
# Token is  is ---- Lemma is  be
# Token is  specialist ---- Lemma is  specialist
# Token is  in ---- Lemma is  in
# Token is  jaaadu ---- Lemma is  jaaadu
# Token is  . ---- Lemma is  .
# Token is  Ticket ---- Lemma is  ticket
# Token is  for ---- Lemma is  for
# Token is  his ---- Lemma is  his
# Token is  show ---- Lemma is  show
# Token is  is ---- Lemma is  be
# Token is  5 ---- Lemma is  5
# Token is  $ ---- Lemma is  $
