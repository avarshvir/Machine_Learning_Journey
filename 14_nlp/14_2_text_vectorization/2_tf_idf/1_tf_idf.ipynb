# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "NLP is fun and powerful",
    "NLP makes text fun"
]

# %%
corpus
# Out:
# ['NLP is fun and powerful', 'NLP makes text fun']

# %%
vectorizer = TfidfVectorizer()

# %%
tfidf_matrix = vectorizer.fit_transform(corpus)

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['and' 'fun' 'is' 'makes' 'nlp' 'powerful' 'text']

# %%
print(tfidf_matrix.toarray())
# Out:
# [[0.49922133 0.35520009 0.49922133 0.         0.35520009 0.49922133
#   0.        ]
#  [0.         0.40993715 0.         0.57615236 0.40993715 0.
#   0.57615236]]

# %%
tfidf_matrix.toarray()
# Out:
# array([[0.49922133, 0.35520009, 0.49922133, 0.        , 0.35520009,
#         0.49922133, 0.        ],
#        [0.        , 0.40993715, 0.        , 0.57615236, 0.40993715,
#         0.        , 0.57615236]])

# %%
print(vectorizer.get_feature_names_out())
print(tfidf_matrix.toarray())
# Out:
# ['and' 'fun' 'is' 'makes' 'nlp' 'powerful' 'text']
# [[0.49922133 0.35520009 0.49922133 0.         0.35520009 0.49922133
#   0.        ]
#  [0.         0.40993715 0.         0.57615236 0.40993715 0.
#   0.57615236]]
